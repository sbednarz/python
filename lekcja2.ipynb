# %% [markdown]
# # Wprowadzenie do Pythona cz. 2

# %%
# wartości liczbowe

a = 100.1
print(a)

# napisy
b = "Ala ma kota"
print(b)
c = " i psa."
# Out:
# 100.1
# Ala ma kota

# %%
print(b+c)
# Out:
# Ala ma kota i psa.

# %%
# listy

a = [] # stworzenie pustej list
b = [0, 21] # lista dwuelementowa
c = [1.3, 1.3e-3, 3]
print(a)
print(b)
print(c)
# Out:
# []
# [0, 21]
# [1.3, 0.0013, 3]

# %%
print(b[0])
# Out:
# 0

# %%
print(b[1])
# Out:
# 21

# %%
print(c[2])
# Out:
# 3

# %%
# "eneble debugger"
d=[[1,2], [10,20], [100,200]]

# %%
print(d[0])
# Out:
# [1, 2]

# %%
print(d[0][0])
# Out:
# 1

# %%
import numpy as np

# %%
# wektory (kolumna lub wiersz w Excelu)

v1 = np.array([1,2,3])
v2 = np.array([11,22,33])

print(v1)
print(v2)
# Out:
# [1 2 3]
# [11 22 33]

# %%
v3 = np.linspace(0,10)
print(v3)
# Out:
# [ 0.          0.20408163  0.40816327  0.6122449   0.81632653  1.02040816
#   1.2244898   1.42857143  1.63265306  1.83673469  2.04081633  2.24489796
#   2.44897959  2.65306122  2.85714286  3.06122449  3.26530612  3.46938776
#   3.67346939  3.87755102  4.08163265  4.28571429  4.48979592  4.69387755
#   4.89795918  5.10204082  5.30612245  5.51020408  5.71428571  5.91836735
#   6.12244898  6.32653061  6.53061224  6.73469388  6.93877551  7.14285714
#   7.34693878  7.55102041  7.75510204  7.95918367  8.16326531  8.36734694
#   8.57142857  8.7755102   8.97959184  9.18367347  9.3877551   9.59183673
#   9.79591837 10.        ]

# %%
v4 = np.linspace(0,10,5)
print(v4)
# Out:
# [ 0.   2.5  5.   7.5 10. ]

# %%
print(v4[0], v4[1])
# Out:
# 0.0 2.5

# %%
# macierze (arkusze Excela)

m1 = np.array([[10,20], [30,40], [50,60]])
print(m1)
# Out:
# [[10 20]
#  [30 40]
#  [50 60]]

# %%
print(m1[0][0])
# Out:
# 10

# %%
print(m1[2][1])
# Out:
# 60

# %%
print(m1[0,0])
# Out:
# 10

# %%
# wybieranie wierszy i kolumn

print(m1[:,0])
print(m1[0,:])
# Out:
# [10 30 50]
# [10 20]

# %%
# WYKRESY

import matplotlib.pyplot as plt
# %matplotlib inline

x1 = np.linspace(-10,10)
y1 = x**2
y2 = -x**2
plt.plot(x1,y1)

# %%
plt.plot(x1,y1)
plt.plot(x1,y2)

# %%
plt.plot(x1,y1)
plt.plot(x1,y2)
plt.plot(0,0,'ro')
plt.xlabel('Oś X')
plt.ylabel('Oś Y')
# Out:
# Text(0, 0.5, 'Oś Y')
